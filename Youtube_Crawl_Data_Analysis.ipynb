# %%
import requests 
import pandas as pd 
import json

# %%
api_key = 'AIzaSyCJDddX8H7wyV-dwirYvs7ZV3ukip4g8DY'

# %%
channel_ID = 'UCgwv23FVv3lqh567yagXfNg' #DisneyMusicVEVO

# %%
url1 = f'https://www.googleapis.com/youtube/v3/channels?part=statistics&key={api_key}&id={channel_ID}'
channel_info = requests.get(url1)
json_data1 = json.loads(channel_info.text)
json_data1
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'HrFT5uk5STFKnL_O--9dnNUR2FY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'knhIvY8Gl3QXciGcNHrn6JjgTv0',
#    'id': 'UCgwv23FVv3lqh567yagXfNg',
#    'statistics': {'viewCount': '28528406784',
#     'subscriberCount': '32700000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '2062'}}]}

# %%
channel_subscribers = int(json_data1['items'][0]['statistics']['subscriberCount'])
channel_videos = int(json_data1['items'][0]['statistics']['videoCount'])
channel_views = int(json_data1['items'][0]['statistics']['viewCount'])

print(f"Total Subsribe = {channel_subscribers}\nTotal Videos: {channel_videos}\nTotal Views: {channel_views}")
# Out:
# Total Subsribe = 32700000
# Total Videos: 2062
# Total Views: 28528406784

# %%
limit = 10  # how many pages of information do you want
video_IDs = []
nextPageToken = ""

for i in range(limit):
    url = f'https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_ID}&maxResults=10&pageToken={nextPageToken}'
    data = json.loads(requests.get(url).text)

    for item in data['items']:
        video_Id = item['id']['videoId']  # Corrected line
        video_IDs.append(video_Id)

    nextPageToken = data.get('nextPageToken', '')  # Corrected line, providing a default value of '' if 'nextPageToken' doesn't exist

# %%
video_IDs
# Out:
# ['oFktUN2C3sk',
#  '4nEiNxr4NpQ',
#  '-RsSl6WtTkM',
#  'TeMWueB8DaI',
#  'HuwPCUzqwKs',
#  'EVYPt97q3vc',
#  'kQDw88hEr2c',
#  '744RngGkqgg',
#  '4LhIen5ALww',
#  '5gnZIwJJrEM',
#  'KP_XkN2v7OM',
#  'AROAcs5RAm8',
#  'q4-LV-DjBiA',
#  '_i_HL9PUVQ4',
#  'ErY3eeRFTFg',
#  'FmWXbwKGovI',
#  '6_jPoXu3qqI',
#  'QZFG80gUPHo',
#  'p8Lrf8zk9JY',
#  'sf3CevfP-E8',
#  'bXDuPFzm-hQ',
#  'iVJbnBfCIKc',
#  'iNAvOxDuU6I',
#  '1AVFBNM0FdU',
#  'Xuq9_NJFfPA',
#  'OVklZIHHj18',
#  'jKKrfr4To14',
#  'l-64INXIolE',
#  'OYNYU3UOgms',
#  'HaJCJK3nX7k',
#  'n_k8H3uct1o',
#  'I1kXl8NzWvg',
#  'NbCNDSRdPtw',
#  'kLeC0EQtfw0',
#  '5hSF2YqeGDE',
#  'sLkDCF_EbqI',
#  '2sst0min-50',
#  'sUNx478Ydb4',
#  '-C2wCcuKmLI',
#  'ThMwHKfzz1I',
#  'zp9b6rjjWNs',
#  '1APv9t_LyOY',
#  'hAYUQ1ltJj0',
#  'hr4TzB7ZQVc',
#  'x3Dl8K6RBcc',
#  'dpza2z4jmDk',
#  'ubZrAmRxy_M',
#  'g8OfYYziIio',
#  'mw5VIEIvuMI',
#  'NalipNz4e3g',
#  '6vzsXJ0D2bM',
#  '62llzl7iKkE',
#  'ukWPR88H53Q',
#  'pJsze1Nx-bg',
#  'bvWRMAU6V-c',
#  'cG-dCOM33nQ',
#  'S-wSCKaHJ6Y',
#  'axySrE0Kg6k',
#  'BaSf-ddZxB8',
#  'ILRs2r6lcHY',
#  'ZDcr9VrUrgw',
#  'SgXpsZa8_i4',
#  'eitDnP0_83k',
#  'BS0T8Cd4UhA',
#  'tSDcbucrWmw',
#  '5WzswZXTMZQ',
#  '6X_84QWvH68',
#  '6vzsXJ0D2bM',
#  '62llzl7iKkE',
#  'ukWPR88H53Q',
#  'zBG-sEGlULs',
#  'ZNra8eK0K6k',
#  '_dyvXcv3ej0',
#  'sBAN0S3rW_I',
#  'r9o1QS-itsU',
#  'mLsUEJPXubc',
#  'pAzFRfzwT-g',
#  'T9GmO_WFhjQ',
#  'qMuc20T4AC8',
#  'lvjkBcBBrmE',
#  'EPccNJ9bffQ',
#  'k-t4vqd534Y',
#  '0qj67KE5VXI',
#  '2YDKxcdIXBs',
#  '4Vv-zcAoer8',
#  'U4WPjBZy-7s',
#  'zBG-sEGlULs',
#  'ZNra8eK0K6k',
#  '_dyvXcv3ej0',
#  'sBAN0S3rW_I',
#  'r9o1QS-itsU',
#  'mLsUEJPXubc',
#  'pAzFRfzwT-g',
#  'T9GmO_WFhjQ',
#  'qMuc20T4AC8',
#  'lvjkBcBBrmE',
#  '1at7kKzBYxI',
#  'GX3OEfjbw4Y',
#  '1C7gqWHNDyc',
#  'AH0geUR9WTA']

# %%
data_df = pd.DataFrame(columns=['video_id','channel_id','published_date',
                             'video_title','video_description','likes',
                             'views','comment_count'])
data_df.head()
# Out:
# Empty DataFrame
# Columns: [video_id, channel_id, published_date, video_title, video_description, likes, views, comment_count]
# Index: []

# %%
data
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'vYu5g5uCx4HfjRrc4u-44Y5QG_Q',
#  'nextPageToken': 'CGQQAA',
#  'prevPageToken': 'CFoQAQ',
#  'regionCode': 'VN',
#  'pageInfo': {'totalResults': 2443, 'resultsPerPage': 10},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'O97QlGgYkyLIAtJAfUreCsbr0JQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'r9o1QS-itsU'},
#    'snippet': {'publishedAt': '2019-08-03T02:00:09Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Sarah Jeffery - Queen of Mean (From &quot;Descendants 3&quot;)',
#     'description': 'Disney+ is the only place to stream your favorites from Disney, Pixar, Marvel, Star Wars, National Geographic and more. Access it ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/r9o1QS-itsU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/r9o1QS-itsU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/r9o1QS-itsU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-08-03T02:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'J7L9JzjhWbvILnHqXt3XWkMGe20',
#    'id': {'kind': 'youtube#video', 'videoId': 'mLsUEJPXubc'},
#    'snippet': {'publishedAt': '2022-02-25T13:00:19Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Nobody Like U (From &quot;Turning Red&quot;/LyricVideo)',
#     'description': "Disney and Pixar's “Turning Red” introduces Mei Lee (voice of Rosalie Chiang), a confident, dorky 13-year-old torn between ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mLsUEJPXubc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mLsUEJPXubc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mLsUEJPXubc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-25T13:00:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'V0ct5zxy3jrnXEZ59g2Lxgzh0dM',
#    'id': {'kind': 'youtube#video', 'videoId': 'pAzFRfzwT-g'},
#    'snippet': {'publishedAt': '2019-09-06T04:00:07Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Zac Efron, Vanessa Hudgens - Gotta Go My Own Way (From &quot;High School Musical 2&quot;)',
#     'description': 'We might find a place in this world someday, but at least for now I gotta go my own way!   Watch Vanessa Hudgens perform ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pAzFRfzwT-g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pAzFRfzwT-g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pAzFRfzwT-g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-09-06T04:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-C4EmBAOMAzAqnAYFfy0tNsoRKA',
#    'id': {'kind': 'youtube#video', 'videoId': 'T9GmO_WFhjQ'},
#    'snippet': {'publishedAt': '2019-05-22T04:00:05Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Will Smith - Arabian Nights (2019) (From &quot;Aladdin&quot;/Audio Only)',
#     'description': 'Stream #Aladdin on Disney+. Disney+ is the only place to stream your favorites from Disney, Pixar, Marvel, Star Wars, National ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/T9GmO_WFhjQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/T9GmO_WFhjQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/T9GmO_WFhjQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-05-22T04:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dJtXvaNAxrFM9zFuFVVvLwbrlps',
#    'id': {'kind': 'youtube#video', 'videoId': 'qMuc20T4AC8'},
#    'snippet': {'publishedAt': '2021-11-19T05:00:30Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Sebastián Yatra - Dos Oruguitas (From &quot;Encanto&quot;/Audio Only)',
#     'description': "See Disney's Encanto now streaming on Disney+ 🕯️✨   Songs from Encanto, by LinManuelMiranda, are coming soon to vinyl ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qMuc20T4AC8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qMuc20T4AC8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qMuc20T4AC8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-19T05:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7cqKvFEwGdQznCJp2AByENgiRHU',
#    'id': {'kind': 'youtube#video', 'videoId': 'lvjkBcBBrmE'},
#    'snippet': {'publishedAt': '2019-05-31T17:00:07Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Good to Be Bad (From &quot;Descendants 3&quot;/Official Video)',
#     'description': 'Disney+ is the only place to stream your favorites from Disney, Pixar, Marvel, Star Wars, National Geographic and more. Access it ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lvjkBcBBrmE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lvjkBcBBrmE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lvjkBcBBrmE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-05-31T17:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nMZqi3Zr98jDKSYLi_r31wiHkgE',
#    'id': {'kind': 'youtube#video', 'videoId': '1at7kKzBYxI'},
#    'snippet': {'publishedAt': '2019-08-06T04:00:01Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Will Smith - Friend Like Me (from Aladdin) (Official Video)',
#     'description': 'Stream #Aladdin on Disney+. Disney+ is the only place to stream your favorites from Disney, Pixar, Marvel, Star Wars, National ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1at7kKzBYxI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1at7kKzBYxI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1at7kKzBYxI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-08-06T04:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'b7vIe1GFTl9CF6_9E9Zz1r3WJEo',
#    'id': {'kind': 'youtube#video', 'videoId': 'GX3OEfjbw4Y'},
#    'snippet': {'publishedAt': '2018-08-24T15:26:24Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Dove Cameron - Born Ready (From “Marvel Rising”)',
#     'description': 'See Dove Cameron voice Ghost-Spider in the Marvel Rising: Initiation special!!! Watch here: https://youtu.be/EWh9JyUded8 Dove ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GX3OEfjbw4Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GX3OEfjbw4Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GX3OEfjbw4Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-08-24T15:26:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tTk40Rp6AtVhM8Wl5fy0eUqrySs',
#    'id': {'kind': 'youtube#video', 'videoId': '1C7gqWHNDyc'},
#    'snippet': {'publishedAt': '2020-06-26T04:00:01Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Mitchell Hope, Jeff Lewis - Did I Mention (From &quot;Descendants&quot;/Sing-Along)',
#     'description': '"Did I mention that I\'m in love with you?! Sing along to ""Did I Mention"" with Mitchell Hope from Descendants and watch ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1C7gqWHNDyc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1C7gqWHNDyc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1C7gqWHNDyc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-06-26T04:00:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wqr7ik0lmZOGkQlFULtY7pD9bZU',
#    'id': {'kind': 'youtube#video', 'videoId': 'AH0geUR9WTA'},
#    'snippet': {'publishedAt': '2020-07-01T04:02:00Z',
#     'channelId': 'UCgwv23FVv3lqh567yagXfNg',
#     'title': 'Joe Jonas - Gotta Find You (From &quot;Camp Rock&quot;/Sing-Along)',
#     'description': '"You\'re the voice I hear inside my head! The reason that I\'m singing! I need to find you!   Sing along to ""Gotta Find You"" with Joe ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AH0geUR9WTA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AH0geUR9WTA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AH0geUR9WTA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DisneyMusicVEVO',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-07-01T04:02:00Z'}}]}

# %%
for i, video_Id in enumerate(video_IDs):
    url = f'https://www.googleapis.com/youtube/v3/videos?part=statistics,snippet&key={api_key}&id={video_Id}'
    data = json.loads(requests.get(url).text)
    
    channel_ID = data['items'][0]['snippet']['channelId']
    published_date = data['items'][0]['snippet']['publishedAt']
    video_title = data['items'][0]['snippet']['title']
    video_description = data['items'][0]['snippet']['description']
    likes = data['items'][0]['statistics']['likeCount']
    views = data['items'][0]['statistics']['viewCount']
    comment_count = data['items'][0]['statistics']['commentCount']
    row = [video_Id, channel_ID, published_date, video_title, video_description, likes, 
           views, comment_count]
    data_df.loc[i] = row

# %%
data_df.to_csv('youtube_disney_raw_data.csv',index=False)
